# %% [markdown]
# В качестве проекта вам нужно выбрать один из двух вариантов задания.
# Вариант 1 подразумевает работу с использованием материала курса. Вариант 2 - для продвинутых студентов - предполагает знакомство с анализом данных.
#
# Работу можно делать в группе до 3-х человек. При этом каждый участник должен присутствовать на защите и понимать, как устроен весь код проекта.
#
# Если на защите становится очевидно несамостоятельное выполнение проекта (участники не могут ответить на простые вопросы по проекту), за весь проект выставляется 0 баллов.

# %% [markdown]
# # Вариант 1

# %% [markdown]
# В рамках этого проекта вам необходимо написать чат-бота и (при желании) сделать для него интерфейс.
# Максимальная оценка за работу - 10 баллов.
#
# ### Дедлайн
# **Сдача проекта на платформе**:
# 17 июня 23.59
#
# **Защита**: 24.06
#
#
# ### Защита проекта
#
# Презентация в день экзамена. Представление вашего проекта.
# Могут быть заданы вопросы как по проекту, так и по всему курсу.
# За защиту выставляется 2 балла, но если вы пропускаете защиту, вы получаете 0 за проект, даже если отправили его вовремя. Если на защите присутствуют не все участники группы, они получают оценку, а отсутствующий получает 0 баллов за весь проект.
#
# Участники группы могут получить разные оценки за защиту.
#
# В этом задании вам нужно написать программу-чат-бота, которая общается с пользователем в виде текста: выводит текст, считывает ответы пользователя и в зависимости от этих ответов дает советы.
#
# Это может быть, например:
# система, которая дает рекомендацию: например, советует еду или напиток, хобби, вид спорта, музыку или фильм; помогает по интересам подобрать профессию и советует топовые вузы, где ей обучают;
# интерактивное приключение: история, в которой присутствуют развилки и пользователь может сделать выбор.
# Вы можете использовать идеи из примеров выше или предложить свой вариант.
#
#
# **Формат сдачи:**
# Для сдачи этого задания необходимо загрузить следующие файлы:
#
# Файл jupyter notebook (*.ipynb), который содержит:
# * ячейки типа markdown с коротким текстовым описанием созданного чат-бота: что это за программа, какую задачу она решает?
# * ячейку типа code, в которой содержится вся написанная программа - при запуске этой ячейки начинается работа с чат-ботом.
#
# ИЛИ:
# * Файл .py, который содержит всю написанную программу
# * Файл pdf, который содержит описание бота
#
# Если ваш бот оформлен как приложение или бот в телеграме - приложить файл или ник бота.
#
# Критерии:
# 1. Практическая применимость (**1 балл**). Программа решает некоторую практическую задачу, не является набором бессмысленных переходов, представляет собой цельную программу, выполняющую заданную цель. Достаточное описание присутствует в первой ячейке.
#
# 2. У программы есть как минимум 3 принципиально разных окончания (**0.5**)
#
# 3. Как минимум одно сложное условие с использованием or или and (**0.5**)
#
# 4. Уместное использование циклов (**0.5**)
#
# 5. Наличие хотя бы одной функции с её уместным использованием (**0.5**)
#
# 6. Наличие хотя бы одной вложенной структуры данных ИЛИ словаря ИЛИ множества (**0.5**)
#
# 5. Существует как минимум одна часть программы, которая повторяется, пока не будет выполнено определенное условие (**0.5**)
#
# 6.
# Код оформлен в соответствии со стандартом pep-8 (не более 2-ух недочетов) - **0.5**
#
# 7. Пояснения для пользователя, которые объясняют, какой текст можно ввести на каждом шаге (не просто появляющиеся пустые поля) (**0.5**)
# 8. Наличие комментариев к работе программы (**0.5**)
# 9. Код работает на всех вариантах запуска, не прекращает свою работу при неверном вводе и не выдает ошибок ни при каких условиях (**1 балл**)
# 10. Оформление как файл .exe или как бот в телеграме. Пример, как это можно сделать, вы можете найти в прикрепленном архиве bot_sql.zip или в других источниках. (**1.5**)
# 11. Защита проекта (**2 балла**)

# %% [markdown]
# # Вариант 2

# %% [markdown]
# В рамках этого проекта вам необходимо провести исследование по анализу данных.
# Для этого вы можете самостоятельно изучить материал, приведенный в архиве pandas_intro.zip
#
# Для выполнения задания вам необходимо собрать данные с помощью скрейпинга (см. неделю 10 онлайн-курса). Вы также можете использовать готовые данные (например, с worldbank, kaggle).
#
# **Минимальные требования по объему данных**: 300 строк и 6 столбцов с различными типами переменных (количественные, категориальные). Если датасет получается меньше заявленных размеров, напишите семинаристу и получите одобрение в случае невозможности собрать больше данных.
#
#
# **Формат сдачи:** ipynb с кодом и описанием, а также файлы с данными.
# Максимальная оценка за работу - 10 баллов.
#
# ### Дедлайн
# **Сдача проекта на платформе**:
# 17 июня 23.59
#
# **Защита**: 24.06
#
#
# ### Оформление и структура (1 балл)
# 1. Сформулирована тема исследования
# 2. Присутствуют подробные комментарии к коду в ячейках markdown.
# 3. Ваш проект должен содержать только рабочий код
# 4. У вашего проекта четкая и ясная структура.
#
# ### Защита проекта (2 балла)
#
# Презентация в день экзамена. Представление вашего проекта.
# Могут быть заданы вопросы как по проекту, так и по всему курсу.
# За защиту выставляется 2 балла, но если вы пропускаете защиту, вы получаете 0 за проект, даже если отправили его вовремя. Если на защите присутствуют не все участники группы, они получают оценку, а отсутствующий получает 0 баллов за весь проект.
#
# Участники группы могут получить разные оценки за защиту.

# %% [markdown]
# ## Задание 1.1 (1 балл)
#
# Выберите тему исследования и данные. Соберите данные с помощью скрейпинга (посмотрите соответствующую неделю в онлайн-курсе).Также вы можете использовать готовые датасеты из любых источников (в этом случае считайте данные из файла и прикрепите соответствующие файлы при сдаче проекта).
# Опишите, как устроены ваши данные.

# %% [markdown]
# ## Задание 2 (2 балла)
# Постройте минимум два графика разного типа (линейный, столбчатая диаграмма, диаграмма рассеяния, boxplot) по вашим данным. Опишите, что они показывают и какие выводы по ним можно сделать.
# Не забудьте про наименование графика и осей.

# %% [markdown]
# ## Задание 3 (3.5 балла)
# Выберете из ваших данных те, которые содержат текст (например, посты в группе). Если среди ваших данных таких нет, найдите текст по той же теме, что и датасет, сохраните его в файл, считайте данные из файла и работайте с ними. </br>
# * Предварительно удалите стоп-слова, избавьтесь от пунктуации (**1 балл**). Список стоп-слов вы можете определить по своему усмотрению.
# * лемматизируйте (приведите к стандартной форме, например, сделал -> сделать) слова из текста с помощью pymorphy. (**0.5 балла**) Документацию можно прочитать здесь https://pymorphy2.readthedocs.io/en/stable/user/guide.html
# * Составьте словарь частотностей слов по вашему тексту. (**1 балл**)
# * Выведите топ-10 самых часто встречающихся слов. (**1 балл**)

# %% [markdown]
# ## Задание 4 (0.5 балла)
# Сделайте выводы по данным.
